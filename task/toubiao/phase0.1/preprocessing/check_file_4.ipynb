# %%
DATA_FOLDER = '/Users/AlexG/Documents/2025/toubiao/工程7.0'
FILE_123 = 'merge-123.tab'
FILE_4 = '4.特征码表.csv'
FILE_5 = '5.专家评分表.csv'

# %%
import os
import pandas as pd
path4 = os.path.join(DATA_FOLDER, FILE_4)

df4 = pd.read_csv(path4)
df4.head()
# Out:
# /Users/AlexG/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3550: DtypeWarning: Columns (8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                       标段编号                            标段名称  \
# 0  K3209220001000005001001  江苏滨海经济开发区管理委员会“智慧园区”智能化工程总承包项目
# 1  K3209220001000005001001  江苏滨海经济开发区管理委员会“智慧园区”智能化工程总承包项目
# 2  K3209220001000005001001  江苏滨海经济开发区管理委员会“智慧园区”智能化工程总承包项目
# 3  K3209220001000005001001  江苏滨海经济开发区管理委员会“智慧园区”智能化工程总承包项目
# 4  B3209810001000102001001          弶港镇有机更新二期“先行区”周边景观提升工程
#
#                 投标人代码                                              投标人名称  \
# 0  91320000134751512X      牵头人：中邮建技术有限公司；成员：中电鸿信信息科技有限公司；成员：华设设计集团股份有限公司
# 1  9132139132113451X0                    牵头人：普瑞达科技集团有限公司；成员：铭扬工程设计集团有限公司
# 2  91320000551171586G                                     江苏移动信息系统集成有限公司
# 3  9132090031398037XC  牵头人：江苏北电兴发科技有限公司；成员：中国联合网络通信有限公司盐城市分公司；成员：中讯邮电...
# 4  91320925MA1WLLEN7E                                       江苏禹创建设工程有限公司
#
#        投标联系人电话              加密锁号                        zaojiasuo1  \
# 0  18068866682  84B748210167280C                               NaN
# 1  18932296706  EC6B9C29057D260A                               NaN
# 2  13770011719           9745655                               NaN
# 3  13921899055  ACA8482117287208                               NaN
# 4  13851170847        1300187702  cc1f2cf07519488884889e97741a67c4
#
#                                                  制作码 MAC地址 下载招标文件IP  下载招标文件时间  \
# 0  9A-D5-F1-6F-51-12@ZDED8QQABEE3532C@BFEBFBFF000...   NaN      NaN       NaN
# 1  D4-5D-64-02-F4-22@50026B7782BD822C0001A994@BFE...   NaN      NaN       NaN
# 2  28-DF-EB-C4-F0-13@CYA3N093210203U0800C4674D@BF...   NaN      NaN       NaN
# 3  2C-EA-7F-17-F9-42@TW07YGY09DH009CP01E44AC18A86...   NaN      NaN       NaN
# 4  50EBF6BA054B@tigo SSD 256GB、WDC WD10EZEX-00BBH...   NaN      NaN       NaN
#
#          投标文件上传IP          投标文件上传时间  开标远程解密IP 所属项目类型  项目所在行政区域 数据来源  \
# 0   117.93.180.75   2023/2/14 20:08       NaN     住建  320922.0   盐城
# 1  221.231.27.170    2023/2/15 8:21       NaN     住建  320922.0   盐城
# 2   39.144.151.68   2023/2/14 23:12       NaN     住建  320922.0   盐城
# 3   117.93.104.94   2023/2/14 16:59       NaN     住建  320922.0   盐城
# 4    49.83.199.59  2022/12/30 16:10       NaN     住建  320981.0   盐城
#
#                                  标段唯一标识
# 0  e454d34d-c7db-47c9-b2a3-1643eee88279
# 1  e454d34d-c7db-47c9-b2a3-1643eee88279
# 2  e454d34d-c7db-47c9-b2a3-1643eee88279
# 3  e454d34d-c7db-47c9-b2a3-1643eee88279
# 4  e54bcfea-8f84-4a88-82e7-3bc55a7db482

# %%
col1='标段唯一标识'
# col2='投标人代码'
col2='投标人名称'
groups = df4.groupby(by=[col1, col2]).count()
groups = groups.sort_values(by='标段编号', ascending=False)
groups.head()
# Out:
#                                                    标段编号  标段名称  投标人代码  投标联系人电话  \
# 标段唯一标识                               投标人名称
# 001330d3-6f28-4c2d-bdc8-17f1f886d756 万地建设集团有限公司       2     2      2        2
#                                      中亿建工集团有限公司       2     2      2        2
#                                      中亿投工程管理有限公司      2     2      2        2
#                                      中安盐华建设工程有限公司     2     2      2        2
#                                      中宏建兴建设集团有限公司     2     2      2        2
#
#                                                    加密锁号  zaojiasuo1  制作码  \
# 标段唯一标识                               投标人名称
# 001330d3-6f28-4c2d-bdc8-17f1f886d756 万地建设集团有限公司       2           1    2
#                                      中亿建工集团有限公司       2           1    2
#                                      中亿投工程管理有限公司      2           1    2
#                                      中安盐华建设工程有限公司     2           1    2
#                                      中宏建兴建设集团有限公司     2           1    2
#
#                                                    MAC地址  下载招标文件IP  下载招标文件时间  \
# 标段唯一标识                               投标人名称
# 001330d3-6f28-4c2d-bdc8-17f1f886d756 万地建设集团有限公司        2         2         0
#                                      中亿建工集团有限公司        2         2         0
#                                      中亿投工程管理有限公司       2         2         0
#                                      中安盐华建设工程有限公司      2         2         0
#                                      中宏建兴建设集团有限公司      2         2         0
#
#                                                    投标文件上传IP  投标文件上传时间  \
# 标段唯一标识                               投标人名称
# 001330d3-6f28-4c2d-bdc8-17f1f886d756 万地建设集团有限公司           2         2
#                                      中亿建工集团有限公司           2         2
#                                      中亿投工程管理有限公司          2         2
#                                      中安盐华建设工程有限公司         2         2
#                                      中宏建兴建设集团有限公司         2         2
#
#                                                    开标远程解密IP  所属项目类型  项目所在行政区域  \
# 标段唯一标识                               投标人名称
# 001330d3-6f28-4c2d-bdc8-17f1f886d756 万地建设集团有限公司           0       2         2
#                                      中亿建工集团有限公司           0       2         2
#                                      中亿投工程管理有限公司          0       2         2
#                                      中安盐华建设工程有限公司         0       2         2
#                                      中宏建兴建设集团有限公司         0       2         2
#
#                                                    数据来源
# 标段唯一标识                               投标人名称
# 001330d3-6f28-4c2d-bdc8-17f1f886d756 万地建设集团有限公司       2
#                                      中亿建工集团有限公司       2
#                                      中亿投工程管理有限公司      2
#                                      中安盐华建设工程有限公司     2
#                                      中宏建兴建设集团有限公司     2

# %%
# Compute group sizes
group_sizes = df4.groupby(by=[col1, col2])['zaojiasuo1'].transform('size')

# Build mask: drop if group size > 1 and col3 is null
mask = ~((group_sizes > 1) & (df4['zaojiasuo1'].isnull()))

# Apply mask
df_filtered = df4[mask]
print(df4.shape[0], df_filtered.shape[0])
df_dedup = df_filtered.drop_duplicates(subset=[col1, col2], keep=False)
print(df4.shape[0], df_filtered.shape[0], df_dedup.shape[0])
# Out:
# 421897 245226
# 421897 245226 245226

# %%
sample_df = df4[df4['投标人名称'] == '万地建设集团有限公司']
sample_df = sample_df[sample_df['标段唯一标识'] == '001330d3-6f28-4c2d-bdc8-17f1f886d756']
sample_df.head()
# Out:
#                                         标段编号                     标段名称  \
# 85294                B3209250001000020002001   2023小区雨污分流及清淤养护工程（二标段）
# 258161  001330d3-6f28-4c2d-bdc8-17f1f886d756  B3209250001000020002001
#
#                      投标人代码       投标人名称      投标联系人电话        加密锁号  \
# 85294   91321081MA1XWDXU4E  万地建设集团有限公司  15905523700  1326766585
# 258161  91321081MA1XWDXU4E  万地建设集团有限公司  15905523700  1326766585
#
#                               zaojiasuo1  \
# 85294   9733c80100070200b83a0009002f0012
# 258161                               NaN
#
#                                                       制作码              MAC地址  \
# 85294   D85ED34ACE55@WDC WD10EZEX-00BBHA0、WDC WDS240G2...  D8-5E-D3-4A-CE-55
# 258161  D85ED34ACE55@WDC WD10EZEX-00BBHA0、WDC WDS240G2...  D8-5E-D3-4A-CE-55
#
#               下载招标文件IP  下载招标文件时间        投标文件上传IP         投标文件上传时间  开标远程解密IP  \
# 85294   117.91.107.196       NaN  117.91.107.196  2023/6/19 16:11       NaN
# 258161  117.91.107.196       NaN  117.91.107.196  2023/6/19 16:11       NaN
#
#        所属项目类型  项目所在行政区域 数据来源                                标段唯一标识
# 85294      住建  320925.0   盐城  001330d3-6f28-4c2d-bdc8-17f1f886d756
# 258161     住建  320925.0   盐城  001330d3-6f28-4c2d-bdc8-17f1f886d756

# %%
# Compute group sizes
group_sizes = sample_df.groupby(by=[col1, col2])['zaojiasuo1'].transform('size')
display(group_sizes)

# Build mask: drop if group size > 1 and col3 is null
mask = ~((group_sizes > 1) & (sample_df['zaojiasuo1'].isnull()))
display(mask)

# Apply mask
df_filtered = sample_df[mask]
df_filtered
# Out:
# 85294     2
# 258161    2
# Name: zaojiasuo1, dtype: int64
# 85294      True
# 258161    False
# Name: zaojiasuo1, dtype: bool
#                           标段编号                    标段名称               投标人代码  \
# 85294  B3209250001000020002001  2023小区雨污分流及清淤养护工程（二标段）  91321081MA1XWDXU4E
#
#             投标人名称      投标联系人电话        加密锁号                        zaojiasuo1  \
# 85294  万地建设集团有限公司  15905523700  1326766585  9733c80100070200b83a0009002f0012
#
#                                                      制作码              MAC地址  \
# 85294  D85ED34ACE55@WDC WD10EZEX-00BBHA0、WDC WDS240G2...  D8-5E-D3-4A-CE-55
#
#              下载招标文件IP  下载招标文件时间        投标文件上传IP         投标文件上传时间  开标远程解密IP  \
# 85294  117.91.107.196       NaN  117.91.107.196  2023/6/19 16:11       NaN
#
#       所属项目类型  项目所在行政区域 数据来源                                标段唯一标识
# 85294     住建  320925.0   盐城  001330d3-6f28-4c2d-bdc8-17f1f886d756
